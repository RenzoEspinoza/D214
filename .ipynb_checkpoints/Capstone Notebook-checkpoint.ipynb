# %%
import numpy as np
import matplotlib as plt
import pandas as pd
import seaborn as sns

# %%
prevalence = pd.read_excel('datasets/medicare_dashboard_2018.xlsx', sheet_name='Prevalence')

# %%
prevalence
# Out:
#           State    County                           Chronic Conditions  \
# 0      National  National                                Alcohol Abuse
# 1      National  National                 Alzheimer's Disease/Dementia
# 2      National  National                                    Arthritis
# 3      National  National                                       Asthma
# 4      National  National                          Atrial Fibrillation
# ...         ...       ...                                          ...
# 68266   Unknown   Unknown                                 Hypertension
# 68267   Unknown   Unknown                       Ischemic Heart Disease
# 68268   Unknown   Unknown                                 Osteoporosis
# 68269   Unknown   Unknown  Schizophrenia and Other Psychotic Disorders
# 68270   Unknown   Unknown                                       Stroke
#
#        Count of Beneficiaries in County  Chronic Condition Prevalence (%)
# 0                            33503234.0                            2.0793
# 1                            33503234.0                           10.7782
# 2                            33503234.0                           33.4688
# 3                            33503234.0                            4.9723
# 4                            33503234.0                            8.4052
# ...                                 ...                               ...
# 68266                               NaN                               NaN
# 68267                               NaN                               NaN
# 68268                               NaN                               NaN
# 68269                               NaN                               NaN
# 68270                               NaN                               NaN
#
# [68271 rows x 5 columns]

# %%
prevalence.isnull().sum()
# Out:
# State                                  0
# County                                 0
# Chronic Conditions                     0
# Count of Beneficiaries in County    1071
# Chronic Condition Prevalence (%)    6216
# dtype: int64

# %%
prevalence.dropna(inplace=True)

# %%
prevalence.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62055 entries, 0 to 68249
# Data columns (total 5 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   State                             62055 non-null  object
#  1   County                            62055 non-null  object
#  2   Chronic Conditions                62055 non-null  object
#  3   Count of Beneficiaries in County  62055 non-null  float64
#  4   Chronic Condition Prevalence (%)  62055 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.8+ MB

# %%
spending = pd.read_excel('datasets/medicare_dashboard_2018.xlsx', sheet_name='Spending and Utilization')

# %%
spending
# Out:
#           State    County Number of Chronic Conditions  \
# 0      National  National                       0 to 1
# 1      National  National                       2 to 3
# 2      National  National                       4 to 5
# 3      National  National                           6+
# 4       Alabama   Autauga                       0 to 1
# ...         ...       ...                          ...
# 12999   Wyoming     State                           6+
# 13000   Unknown   Unknown                       0 to 1
# 13001   Unknown   Unknown                       2 to 3
# 13002   Unknown   Unknown                       4 to 5
# 13003   Unknown   Unknown                           6+
#
#        Count of Beneficiaries in County  Prevalence (%)  \
# 0                              10416133           31.09
# 1                               9741510           29.08
# 2                               7415816           22.13
# 3                               5929775           17.70
# 4                                  1338           26.58
# ...                                 ...             ...
# 12999                              9060            9.42
# 13000                             47002             NaN
# 13001                              5631             NaN
# 13002                              3807             NaN
# 13003                              1833             NaN
#
#        Per Capita Medicare Spending ($)  ED Visits per 1,000 Beneficiaries  \
# 0                             2061.2847                           174.0199
# 1                             5843.5271                           400.7496
# 2                            11036.0516                           726.4933
# 3                            30118.6940                          1922.2156
# 4                             2205.6662                           210.7623
# ...                                 ...                                ...
# 12999                        32474.0427                          2302.5386
# 13000                               NaN                                NaN
# 13001                               NaN                                NaN
# 13002                               NaN                                NaN
# 13003                               NaN                                NaN
#
#        30 Day Readmission Rate (%)
# 0                           0.0591
# 1                           0.0755
# 2                           0.1072
# 3                           0.2270
# 4                              NaN
# ...                            ...
# 12999                       0.2079
# 13000                          NaN
# 13001                          NaN
# 13002                          NaN
# 13003                          NaN
#
# [13004 rows x 8 columns]

# %%
spending.isnull().sum()
# Out:
# State                                   0
# County                                  0
# Number of Chronic Conditions            0
# Count of Beneficiaries in County        0
# Prevalence (%)                        248
# Per Capita Medicare Spending ($)      248
# ED Visits per 1,000 Beneficiaries     500
# 30 Day Readmission Rate (%)          5148
# dtype: int64

# %%
spending.drop(spending.columns[[6,7]], axis=1, inplace=True)

# %%
spending.dropna(inplace=True)

# %%
spending.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12756 entries, 0 to 12999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   State                             12756 non-null  object
#  1   County                            12756 non-null  object
#  2   Number of Chronic Conditions      12756 non-null  object
#  3   Count of Beneficiaries in County  12756 non-null  int64
#  4   Prevalence (%)                    12756 non-null  float64
#  5   Per Capita Medicare Spending ($)  12756 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 697.6+ KB

# %%
condition = spending[(spending.County == 'State') | (spending.County == 'National')].index
spending.drop(condition, inplace=True)

# %%
condition = prevalence[(prevalence.County == 'State') | (prevalence.County == 'National')].index
prevalence.drop(condition, inplace=True)

# %%
walkability = pd.read_csv('datasets/epa_walkability_jan_2021.csv')

# %%
walkability
# Out:
#         OBJECTID       GEOID10       GEOID20  STATEFP  COUNTYFP  TRACTCE  \
# 0              1  4.811300e+11  4.811300e+11       48       113     7825
# 1              2  4.811300e+11  4.811300e+11       48       113     7825
# 2              3  4.811300e+11  4.811300e+11       48       113     7825
# 3              4  4.811300e+11  4.811300e+11       48       113     7824
# 4              5  4.811300e+11  4.811300e+11       48       113     7824
# ...          ...           ...           ...      ...       ...      ...
# 220735    220736  7.803100e+11  7.803100e+11       78        30   961000
# 220736    220737  7.803100e+11  7.803100e+11       78        30   961000
# 220737    220738  7.803100e+11  7.803100e+11       78        30   961000
# 220738    220739  7.803100e+11  7.803100e+11       78        30   960700
# 220739    220740  7.803100e+11  7.803100e+11       78        30   960200
#
#         BLKGRPCE    CSA                  CSA_Name     CBSA  ...         D5DRI  \
# 0              4  206.0  Dallas-Fort Worth, TX-OK  19100.0  ...      0.184697
# 1              2  206.0  Dallas-Fort Worth, TX-OK  19100.0  ...      0.323221
# 2              3  206.0  Dallas-Fort Worth, TX-OK  19100.0  ...      0.314628
# 3              1  206.0  Dallas-Fort Worth, TX-OK  19100.0  ...      0.229821
# 4              2  206.0  Dallas-Fort Worth, TX-OK  19100.0  ...      0.164863
# ...          ...    ...                       ...      ...  ...           ...
# 220735         2    NaN                       NaN      NaN  ... -99999.000000
# 220736         3    NaN                       NaN      NaN  ... -99999.000000
# 220737         5    NaN                       NaN      NaN  ... -99999.000000
# 220738         3    NaN                       NaN      NaN  ... -99999.000000
# 220739         2    NaN                       NaN      NaN  ... -99999.000000
#
#                 D5DE         D5DEI  D2A_Ranked  D2B_Ranked  D3B_Ranked  \
# 0           0.000476      0.137707           6          14          15
# 1           0.000801      0.231868           3          10          12
# 2           0.000736      0.213146           1           1           7
# 3           0.000708      0.205018          16          10          17
# 4           0.000433      0.125296           4           7          11
# ...              ...           ...         ...         ...         ...
# 220735 -99999.000000 -99999.000000           1           1          20
# 220736 -99999.000000 -99999.000000           1           1          20
# 220737 -99999.000000 -99999.000000           1           1          20
# 220738 -99999.000000 -99999.000000           1           1          10
# 220739 -99999.000000 -99999.000000           1           1          12
#
#         D4A_Ranked  NatWalkInd  Shape_Length    Shape_Area
# 0               17   14.000000   3110.360820  2.978361e+05
# 1               14   10.833333   3519.469110  4.849451e+05
# 2               17    8.333333   1697.091802  1.067059e+05
# 3               17   15.666667   2922.609204  4.818284e+05
# 4               14   10.166667   3731.971773  6.876848e+05
# ...            ...         ...           ...           ...
# 220735           1    7.333333   3414.446949  3.355857e+05
# 220736           1    7.333333   2421.025608  2.924305e+05
# 220737           1    7.333333   1955.909418  1.619395e+05
# 220738           1    4.000000  16896.768870  1.038966e+07
# 220739           1    4.666667   3890.488237  6.114601e+05
#
# [220740 rows x 117 columns]

# %%
print('Unique counties in EPA dataset:')
print(len(walkability.CSA_Name.unique()))
# Out:
# Unique counties in EPA dataset:
# 176

# %%
print('Unique counties in CMS dataset:')
print(len(spending.County.unique().tolist()))
# Out:
# Unique counties in CMS dataset:
# 1846

# %%
walkability.STATEFP = walkability.STATEFP.astype('str')
walkability.COUNTYFP = walkability.COUNTYFP.astype('str')

# %%
walkability.COUNTYFP = walkability.COUNTYFP.str.pad(3, fillchar='0')
walkability.COUNTYFP
# Out:
# 0         113
# 1         113
# 2         113
# 3         113
# 4         113
#          ...
# 220735    030
# 220736    030
# 220737    030
# 220738    030
# 220739    030
# Name: COUNTYFP, Length: 220740, dtype: object

# %%
walkability['fips'] = walkability.STATEFP + walkability.COUNTYFP

# %%
# filtering dataframe to contain only features that I am interested in
walkability = walkability[['fips', 'NatWalkInd','TotPop',
                           'D1A', 'D1B', 'D1C','R_PCTLOWWAGE']]

# %%
walkability
# Out:
#          fips  NatWalkInd  TotPop        D1A        D1B       D1C  \
# 0       48113   14.000000    1202   6.250422  16.332625  0.896800
# 1       48113   10.833333     710   3.430799   5.955666  0.209707
# 2       48113    8.333333     737  13.843035  27.951553  0.000000
# 3       48113   15.666667     904   3.225246   7.592767  2.124967
# 4       48113   10.166667     948   2.305992   6.373413  0.215136
# ...       ...         ...     ...        ...        ...       ...
# 220735  78030    7.333333    1471   8.761019  18.813808  0.000000
# 220736  78030    7.333333     940   8.040306  13.008412  0.000000
# 220737  78030    7.333333     878  12.545333  21.941838  0.000000
# 220738  78030    4.000000    1278   1.404107   1.485471  0.000000
# 220739  78030    4.666667    1640   4.838135  10.854366  0.000000
#
#         R_PCTLOWWAGE
# 0           0.240291
# 1           0.192405
# 2           0.293737
# 3           0.139211
# 4           0.157168
# ...              ...
# 220735      0.000000
# 220736      0.000000
# 220737      0.000000
# 220738      0.000000
# 220739      0.000000
#
# [220740 rows x 7 columns]

# %%
walkability.isnull().sum()
# Out:
# fips              0
# NatWalkInd        0
# TotPop            0
# D1A             271
# D1B               0
# D1C               0
# R_PCTLOWWAGE      0
# dtype: int64

# %%
walkability[walkability['D1A'].isna()]
# Out:
#          fips  NatWalkInd  TotPop  D1A        D1B  D1C  R_PCTLOWWAGE
# 217783  66010         1.0    1223  NaN  15.933417  0.0           0.0
# 217784  66010         1.0     999  NaN   7.526249  0.0           0.0
# 217785  66010         1.0     525  NaN  16.584285  0.0           0.0
# 217786  66010         1.0     640  NaN   4.520495  0.0           0.0
# 217787  66010         1.0     682  NaN   7.517141  0.0           0.0
# ...       ...         ...     ...  ...        ...  ...           ...
# 218052  69110         1.0    1700  NaN   2.523464  0.0           0.0
# 218053  69120         1.0     654  NaN   2.468680  0.0           0.0
# 218054  69120         1.0       0  NaN   0.000000  0.0           0.0
# 218055  69120         1.0     679  NaN   0.043336  0.0           0.0
# 218056  69120         1.0     706  NaN   4.269841  0.0           0.0
#
# [271 rows x 7 columns]

# %%
walkability.dropna(inplace=True)
# Out:
# C:\Users\Renzo Espinoza\AppData\Local\Temp\ipykernel_16476\1058171967.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   walkability.dropna(inplace=True)

# %%
fips_codes = pd.read_csv('datasets/fips.csv')

# %%
fips_codes
# Out:
#        fips               name state
# 0         0      UNITED STATES   NaN
# 1      1000            ALABAMA   NaN
# 2      1001     Autauga County    AL
# 3      1003     Baldwin County    AL
# 4      1005     Barbour County    AL
# ...     ...                ...   ...
# 3190  56037  Sweetwater County    WY
# 3191  56039       Teton County    WY
# 3192  56041       Uinta County    WY
# 3193  56043    Washakie County    WY
# 3194  56045      Weston County    WY
#
# [3195 rows x 3 columns]

# %%
fips_codes.isnull().sum()
# Out:
# fips      0
# name      0
# state    52
# dtype: int64

# %%
fips_codes.dropna(inplace=True)

# %%
state_initials = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}

# %%
spending.State = spending.State.map(lambda x: state_initials.get(x, x))

# %%
spending.State
# Out:
# 4        AL
# 5        AL
# 6        AL
# 7        AL
# 8        AL
#          ..
# 12991    WY
# 12992    WY
# 12993    WY
# 12994    WY
# 12995    WY
# Name: State, Length: 12548, dtype: object

# %%
prevalence.State = prevalence.State.map(lambda x: state_initials.get(x, x))

# %%
walkability
# Out:
#          fips  NatWalkInd  TotPop        D1A        D1B       D1C  \
# 0       48113   14.000000    1202   6.250422  16.332625  0.896800
# 1       48113   10.833333     710   3.430799   5.955666  0.209707
# 2       48113    8.333333     737  13.843035  27.951553  0.000000
# 3       48113   15.666667     904   3.225246   7.592767  2.124967
# 4       48113   10.166667     948   2.305992   6.373413  0.215136
# ...       ...         ...     ...        ...        ...       ...
# 220735  78030    7.333333    1471   8.761019  18.813808  0.000000
# 220736  78030    7.333333     940   8.040306  13.008412  0.000000
# 220737  78030    7.333333     878  12.545333  21.941838  0.000000
# 220738  78030    4.000000    1278   1.404107   1.485471  0.000000
# 220739  78030    4.666667    1640   4.838135  10.854366  0.000000
#
#         R_PCTLOWWAGE
# 0           0.240291
# 1           0.192405
# 2           0.293737
# 3           0.139211
# 4           0.157168
# ...              ...
# 220735      0.000000
# 220736      0.000000
# 220737      0.000000
# 220738      0.000000
# 220739      0.000000
#
# [220469 rows x 7 columns]

# %%
walkability.replace(-99999, 0, inplace=True)
# Out:
# C:\Users\Renzo Espinoza\AppData\Local\Temp\ipykernel_16476\2874027288.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   walkability.replace(-99999, 0, inplace=True)

# %%
walkability = walkability[walkability.TotPop != 0]

# %%
walkability.describe()
# Out:
#           NatWalkInd         TotPop            D1A            D1B  \
# count  219342.000000  219342.000000  219342.000000  219342.000000
# mean        9.579270    1488.323691       4.553511      10.488798
# std         4.351047     984.808510      13.913730      29.211680
# min         1.000000       2.000000       0.000000       0.000000
# 25%         5.833333     895.000000       0.314051       0.747008
# 50%         9.166667    1270.000000       1.863999       4.366073
# 75%        13.333333    1820.000000       4.180944      10.189268
# max        20.000000   55407.000000    1481.257220    3133.578265
#
#                  D1C   R_PCTLOWWAGE
# count  219342.000000  219342.000000
# mean        3.783203       0.235481
# std        46.521003       0.060380
# min         0.000000       0.000000
# 25%         0.078807       0.202544
# 50%         0.540401       0.232210
# 75%         2.168573       0.266667
# max     14032.760640       1.000000

# %%
#look up when to use median and mean

# %%
grouped = walkability.groupby('fips').agg({'NatWalkInd': 'mean', 'TotPop': 'sum', 
                                 'D1A': 'median', 'D1B': 'median', 'D1C': 'median',
                                 'R_PCTLOWWAGE': 'mean'})

# %%
grouped = grouped.reset_index()

# %%
grouped
# Out:
#        fips  NatWalkInd  TotPop       D1A       D1B       D1C  R_PCTLOWWAGE
# 0     10001    8.384977  174822  0.426021  1.117622  0.143864      0.247562
# 1     10003   11.795993  555133  2.646858  6.765879  1.454312      0.236048
# 2     10005    8.241855  219540  0.678500  0.814619  0.141135      0.268266
# 3      1001    5.234375   55200  0.263939  0.628581  0.076586      0.230803
# 4      1003    6.508961  208107  0.356350  0.608242  0.112992      0.245249
# ...     ...         ...     ...       ...       ...       ...           ...
# 3222   9007    8.963277  163368  0.540723  1.059696  0.305508      0.197325
# 3223   9009   11.241893  859339  2.449562  5.718358  0.823082      0.229919
# 3224   9011    9.258467  268881  0.637035  1.399568  0.297041      0.219882
# 3225   9013    6.715986  151269  0.260281  0.640312  0.112072      0.197252
# 3226   9015    6.755682  116538  0.207061  0.470850  0.097426      0.215526
#
# [3227 rows x 7 columns]

# %%
print('Unique counties in CMS dataset:')
print(len(spending.County.unique().tolist()))
# Out:
# Unique counties in CMS dataset:
# 1846

# %%
fips_codes.name.replace(' County', '', regex=True, inplace=True)

# %%
grouped.fips = grouped.fips.astype('int64')

# %%
walkability = pd.merge(grouped, fips_codes,  how='left', left_on=['fips'], right_on = ['fips'])

# %%
walkability
# Out:
#        fips  NatWalkInd  TotPop       D1A       D1B       D1C  R_PCTLOWWAGE  \
# 0     10001    8.384977  174822  0.426021  1.117622  0.143864      0.247562
# 1     10003   11.795993  555133  2.646858  6.765879  1.454312      0.236048
# 2     10005    8.241855  219540  0.678500  0.814619  0.141135      0.268266
# 3      1001    5.234375   55200  0.263939  0.628581  0.076586      0.230803
# 4      1003    6.508961  208107  0.356350  0.608242  0.112992      0.245249
# ...     ...         ...     ...       ...       ...       ...           ...
# 3222   9007    8.963277  163368  0.540723  1.059696  0.305508      0.197325
# 3223   9009   11.241893  859339  2.449562  5.718358  0.823082      0.229919
# 3224   9011    9.258467  268881  0.637035  1.399568  0.297041      0.219882
# 3225   9013    6.715986  151269  0.260281  0.640312  0.112072      0.197252
# 3226   9015    6.755682  116538  0.207061  0.470850  0.097426      0.215526
#
#             name state
# 0           Kent    DE
# 1     New Castle    DE
# 2         Sussex    DE
# 3        Autauga    AL
# 4        Baldwin    AL
# ...          ...   ...
# 3222   Middlesex    CT
# 3223   New Haven    CT
# 3224  New London    CT
# 3225     Tolland    CT
# 3226     Windham    CT
#
# [3227 rows x 9 columns]

# %%
missing_counties = walkability.loc[walkability.name.isnull()]

# %%
display(missing_counties)
# Out:
#        fips  NatWalkInd  TotPop       D1A       D1B       D1C  R_PCTLOWWAGE  \
# 878    2158    5.166667    8198  0.001950  0.007102  0.000751      0.125000
# 2207  46102    3.796296   14335  0.004051  0.014163  0.002641      0.278732
# 3013  60010    1.000000   23030  0.354127  1.723508  0.000000      0.000000
# 3014  60020    1.000000    1143  0.038186  0.092613  0.000000      0.000000
# 3016  60040    1.000000      17  0.011701  0.028417  0.000000      0.000000
# ...     ...         ...     ...       ...       ...       ...           ...
# 3150  72151    3.507246   34149  0.482509  1.218972  0.000000      0.000000
# 3151  72153    4.559524   36439  1.716170  3.481300  0.000000      0.000000
# 3152  78010    4.277778   50601  0.936674  1.900075  0.000000      0.000000
# 3153  78020    3.857143    4170  1.174064  1.050268  0.000000      0.000000
# 3154  78030    4.729730   51634  1.987209  3.931972  0.000000      0.000000
#
#      name state
# 878   NaN   NaN
# 2207  NaN   NaN
# 3013  NaN   NaN
# 3014  NaN   NaN
# 3016  NaN   NaN
# ...   ...   ...
# 3150  NaN   NaN
# 3151  NaN   NaN
# 3152  NaN   NaN
# 3153  NaN   NaN
# 3154  NaN   NaN
#
# [87 rows x 9 columns]

# %%
spending_walkability = pd.merge(spending, walkability, how='left', left_on=['State', 'County'], right_on=['state', 'name'])

# %%
spending_walkability
# Out:
#       State    County Number of Chronic Conditions  \
# 0        AL   Autauga                       0 to 1
# 1        AL   Autauga                       2 to 3
# 2        AL   Autauga                       4 to 5
# 3        AL   Autauga                           6+
# 4        AL   Baldwin                       0 to 1
# ...     ...       ...                          ...
# 12543    WY  Washakie                           6+
# 12544    WY    Weston                       0 to 1
# 12545    WY    Weston                       2 to 3
# 12546    WY    Weston                       4 to 5
# 12547    WY    Weston                           6+
#
#        Count of Beneficiaries in County  Prevalence (%)  \
# 0                                  1338           26.58
# 1                                  1416           28.13
# 2                                  1249           24.81
# 3                                  1031           20.48
# 4                                  7222           27.66
# ...                                 ...             ...
# 12543                               175            9.92
# 12544                               663           46.56
# 12545                               390           27.39
# 12546                               242           16.99
# 12547                               129            9.06
#
#        Per Capita Medicare Spending ($)     fips  NatWalkInd    TotPop  \
# 0                             2205.6662   1001.0    5.234375   55200.0
# 1                             5553.1539   1001.0    5.234375   55200.0
# 2                            10424.6752   1001.0    5.234375   55200.0
# 3                            27300.1283   1001.0    5.234375   55200.0
# 4                             2205.9072   1003.0    6.508961  208107.0
# ...                                 ...      ...         ...       ...
# 12543                        40937.0233  56043.0    7.812500    8129.0
# 12544                         1995.1567  56045.0    6.366667    7100.0
# 12545                         7390.8903  56045.0    6.366667    7100.0
# 12546                        13631.4736  56045.0    6.366667    7100.0
# 12547                        41638.1079  56045.0    6.366667    7100.0
#
#             D1A       D1B       D1C  R_PCTLOWWAGE      name state
# 0      0.263939  0.628581  0.076586      0.230803   Autauga    AL
# 1      0.263939  0.628581  0.076586      0.230803   Autauga    AL
# 2      0.263939  0.628581  0.076586      0.230803   Autauga    AL
# 3      0.263939  0.628581  0.076586      0.230803   Autauga    AL
# 4      0.356350  0.608242  0.112992      0.245249   Baldwin    AL
# ...         ...       ...       ...           ...       ...   ...
# 12543  0.597772  1.507934  0.485411      0.260915  Washakie    WY
# 12544  0.039457  0.093379  0.015009      0.240944    Weston    WY
# 12545  0.039457  0.093379  0.015009      0.240944    Weston    WY
# 12546  0.039457  0.093379  0.015009      0.240944    Weston    WY
# 12547  0.039457  0.093379  0.015009      0.240944    Weston    WY
#
# [12548 rows x 15 columns]

# %%
missing = spending_walkability.loc[spending_walkability.NatWalkInd.isnull()]
missing = missing.groupby(['State', 'County']).mean()
# Out:
# C:\Users\Renzo Espinoza\AppData\Local\Temp\ipykernel_16476\1317896272.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   missing = missing.groupby(['State', 'County']).mean()

# %%
with pd.option_context('display.max_rows', None):
    display(missing)
# Out:
#                                  Count of Beneficiaries in County  \
# State County
# AK    Aleutians East                                        29.25
#       Aleutians West                                        33.75
#       Anchorage                                           7881.00
#       Bethel                                               308.00
#       Bristol Bay                                           29.25
#       Dillingham                                           101.50
#       Fairbanks North Star                                2623.00
#       Haines                                               135.50
#       Hoonah-Angoon                                         77.75
#       Juneau                                              1102.00
#       Kenai Peninsula                                     2582.75
#       Ketchikan Gateway                                    551.50
#       Kodiak Island                                        348.00
#       Kusilvak                                             118.25
#       Lake and Peninsula                                    37.00
#       Matanuska-Susitna                                   3107.25
#       Nome                                                 178.75
#       North Slope                                          103.50
#       Northwest Arctic                                     112.75
#       Petersburg                                           180.00
#       Prince of Wales-Hyder                                209.00
#       Prince of Wales-Outer Ket                              0.00
#       Sitka                                                314.25
#       Skagway                                               67.00
#       Skagway-Hoonah-Angoon                                  0.00
#       Southeast Fairbanks                                  273.75
#       Valdez-Cordova                                       312.25
#       Wade Hampton                                           0.00
#       Wrangell                                             117.50
#       Wrangell-Petersburg                                    0.00
#       Yakutat                                               26.00
#       Yukon-Koyukuk                                        177.25
# IL    DeWitt                                               637.00
# LA    Acadia                                              2201.25
#       Allen                                                917.25
#       Ascension                                           1566.25
#       Assumption                                           723.75
#       Avoyelles                                           1761.50
#       Beauregard                                          1432.00
#       Bienville                                            620.50
#       Bossier                                             3636.50
#       Caddo                                               8078.75
#       Calcasieu                                           6923.75
#       Caldwell                                             377.50
#       Cameron                                              216.50
#       Catahoula                                            419.50
#       Claiborne                                            640.25
#       Concordia                                            817.00
#       DeSoto                                              1119.00
#       East Baton Rouge                                    8124.75
#       East Carroll                                         230.25
#       East Feliciana                                       547.50
#       Evangeline                                          1482.75
#       Franklin                                             834.75
#       Grant                                                784.75
#       Iberia                                              2668.25
#       Iberville                                            610.00
#       Jackson                                              655.25
#       Jefferson                                           7064.00
#       Jefferson Davis                                     1248.75
#       LaSalle                                              592.50
#       Lafayette                                           6853.00
#       Lafourche                                           2876.50
#       Lincoln                                             1281.25
#       Livingston                                          2141.75
#       Madison                                              375.75
#       Morehouse                                           1031.75
#       Natchitoches                                        1454.25
#       Norton City                       25.0000
#       Petersburg City                   25.0000
#       Poquoson City                     24.9975
#       Portsmouth City                   25.0025
#       Radford City                      25.0000
#       Richmond City                     24.9975
#       Roanoke City                      25.0000
#       Salem City                        25.0000
#       Staunton City                     25.0025
#       Suffolk City                      25.0000
#       Virginia Beach City               25.0025
#       Waynesboro City                   24.9975
#       Williamsburg City                 25.0025
#       Winchester City                   24.9975
#
#                                  Per Capita Medicare Spending ($)  fips  \
# State County
# AK    Aleutians East                                 10776.924775   NaN
#       Aleutians West                                 13352.342350   NaN
#       Anchorage                                      12773.698725   NaN
#       Bethel                                         17053.690750   NaN
#       Bristol Bay                                    28842.374900   NaN
#       Dillingham                                     19212.891975   NaN
#       Fairbanks North Star                           10620.665350   NaN
#       Haines                                         16257.772675   NaN
#       Hoonah-Angoon                                  25251.013800   NaN
#       Juneau                                         14025.600850   NaN
#       Kenai Peninsula                                13387.248575   NaN
#       Ketchikan Gateway                              13901.035850   NaN
#       Kodiak Island                                  15415.927400   NaN
#       Kusilvak                                       15220.821550   NaN
#       Lake and Peninsula                             14762.759075   NaN
#       Matanuska-Susitna                              11356.776200   NaN
#       Nome                                           19286.360950   NaN
#       North Slope                                    21621.238250   NaN
#       Northwest Arctic                               12440.487075   NaN
#       Petersburg                                     18114.578450   NaN
#       Prince of Wales-Hyder                          13457.021375   NaN
#       Prince of Wales-Outer Ket                          0.000000   NaN
#       Sitka                                          20105.929925   NaN
#       Skagway                                        20292.878350   NaN
#       Skagway-Hoonah-Angoon                              0.000000   NaN
#       Southeast Fairbanks                            10744.551925   NaN
#       Valdez-Cordova                                 19843.857875   NaN
#       Wade Hampton                                       0.000000   NaN
#       Wrangell                                       15846.678550   NaN
#       Wrangell-Petersburg                                0.000000   NaN
#       Yakutat                                        19577.808875   NaN
#       Yukon-Koyukuk                                  10487.785950   NaN
# IL    DeWitt                                         12114.504000   NaN
# LA    Acadia                                         12056.941475   NaN
#       Allen                                          12418.240250   NaN
#       Ascension                                      12616.563175   NaN
#       Assumption                                     11706.027050   NaN
#       Avoyelles                                      14149.879400   NaN
#       Beauregard                                     12182.346900   NaN
#       Bienville                                      17072.937875   NaN
#       Bossier                                        13186.024300   NaN
#       Caddo                                          14016.622175   NaN
#       Calcasieu                                      12819.777900   NaN
#       Caldwell                                       13286.140575   NaN
#       Cameron                                        10884.375275   NaN
#       Catahoula                                      12366.200550   NaN
#       Claiborne                                      13839.499775   NaN
#       Concordia                                      14596.798025   NaN
#       DeSoto                                         13021.486725   NaN
#       East Baton Rouge                               14079.335675   NaN
#       East Carroll                                   13627.699225   NaN
#       East Feliciana                                 12732.038400   NaN
#       Evangeline                                     12747.646900   NaN
#       Franklin                                       14827.160825   NaN
#       Grant                                          11979.747775   NaN
#       Iberia                                         13095.841900   NaN
#       Iberville                                      14377.798100   NaN
#       Jackson                                        13348.765700   NaN
#       Jefferson                                      12709.534900   NaN
#       Jefferson Davis                                12519.267075   NaN
#       LaSalle                                        13577.728975   NaN
#       Hoonah-Angoon                       NaN
#       Juneau                              NaN
#       Kenai Peninsula                     NaN
#       Ketchikan Gateway                   NaN
#       Kodiak Island                       NaN
#       Kusilvak                            NaN
#       Lake and Peninsula                  NaN
#       Matanuska-Susitna                   NaN
#       Nome                                NaN
#       North Slope                         NaN
#       Northwest Arctic                    NaN
#       Petersburg                          NaN
#       Prince of Wales-Hyder               NaN
#       Prince of Wales-Outer Ket           NaN
#       Sitka                               NaN
#       Skagway                             NaN
#       Skagway-Hoonah-Angoon               NaN
#       Southeast Fairbanks                 NaN
#       Valdez-Cordova                      NaN
#       Wade Hampton                        NaN
#       Wrangell                            NaN
#       Wrangell-Petersburg                 NaN
#       Yakutat                             NaN
#       Yukon-Koyukuk                       NaN
# IL    DeWitt                              NaN
# LA    Acadia                              NaN
#       Allen                               NaN
#       Ascension                           NaN
#       Assumption                          NaN
#       Avoyelles                           NaN
#       Beauregard                          NaN
#       Bienville                           NaN
#       Bossier                             NaN
#       Caddo                               NaN
#       Calcasieu                           NaN
#       Caldwell                            NaN
#       Cameron                             NaN
#       Catahoula                           NaN
#       Claiborne                           NaN
#       Concordia                           NaN
#       DeSoto                              NaN
#       East Baton Rouge                    NaN
#       East Carroll                        NaN
#       East Feliciana                      NaN
#       Evangeline                          NaN
#       Franklin                            NaN
#       Grant                               NaN
#       Iberia                              NaN
#       Iberville                           NaN
#       Jackson                             NaN
#       Jefferson                           NaN
#       Jefferson Davis                     NaN
#       LaSalle                             NaN
#       Lafayette                           NaN
#       Lafourche                           NaN
#       Lincoln                             NaN
#       Livingston                          NaN
#       Madison                             NaN
#       Morehouse                           NaN
#       Natchitoches                        NaN
#       Orleans                             NaN
#       Ouachita                            NaN
#       Plaquemines                         NaN
#       Pointe Coupee                       NaN
#       Rapides                             NaN
#       Red River                           NaN
#       Richland                            NaN
#       Sabine                              NaN
#       St. Bernard                         NaN
#       St. Charles                         NaN
#       St. Helena                          NaN
#       St. James                           NaN
#       St. John the Baptist                NaN
#       St. Landry                          NaN
#       St. Martin                          NaN
#       St. Mary                            NaN
#       St. Tammany                         NaN
#       Tangipahoa                          NaN
#       Tensas                              NaN
#       Terrebonne                          NaN
#       Union                               NaN
#       Vermilion                           NaN
#       Vernon                              NaN
#       Washington                          NaN
#       Webster                             NaN
#       West Baton Rouge                    NaN
#       West Carroll                        NaN
#       West Feliciana                      NaN
#       Winn                                NaN
# MD    Baltimore City                      NaN
# MO    St. Louis City                      NaN
# NM    Dona Ana                            NaN
# SD    Oglala Lakota                       NaN
#       Shannon                             NaN
# VA    Alexandria City                     NaN
#       Bedford City                        NaN
#       Bristol City                        NaN
#       Buena Vista City                    NaN
#       Charlottesville City                NaN
#       Chesapeake City                     NaN
#       Clifton Forge City                  NaN
#       Colonial Heights City               NaN
#       Covington City                      NaN
#       Danville City                       NaN
#       Emporia City                        NaN
#       Fairfax City                        NaN
#       Falls Church City                   NaN
#       Franklin City                       NaN
#       Fredericksburg City                 NaN
#       Galax City                          NaN
#       Hampton City                        NaN
#       Harrisonburg City                   NaN
#       Hopewell City                       NaN
#       Lexington City                      NaN
#       Lynchburg City                      NaN
#       Manassas City                       NaN
#       Manassas Park City                  NaN
#       Martinsville City                   NaN
#       Newport News City                   NaN
#       Norfolk City                        NaN
#       Norton City                         NaN
#       Petersburg City                     NaN
#       Poquoson City                       NaN
#       Portsmouth City                     NaN
#       Radford City                        NaN
#       Richmond City                       NaN
#       Roanoke City                        NaN
#       Salem City                          NaN
#       Staunton City                       NaN
#       Suffolk City                        NaN
#       Virginia Beach City                 NaN
#       Waynesboro City                     NaN
#       Williamsburg City                   NaN
#       Winchester City                     NaN

# %%
filler = [
    ' City and Borough',
    ' Borough',
    ' Census Area',
    ' Municipality',
    ' Parish'
]
regex = '|'.join(filler)

# %%
fips_codes.name.replace(regex, '', regex=True, inplace=True)

# %%
fips_codes.name.replace('De Witt', 'DeWitt', inplace=True)

# %%
fips_codes.name.replace('La Salle', 'LaSalle', inplace=True)

# %%
fips_codes.name.replace('De Soto', 'DeSoto', inplace=True)

# %%
fips_codes.name.replace('city', 'City', inplace=True, regex=True)

# %%
fips_codes.name.replace('Do̱a', 'Dona', inplace=True, regex=True)

# %%
spending.County.replace('La Salle', 'LaSalle', inplace=True)

# %%
prevalence.County.replace('La Salle', 'LaSalle', inplace=True)

# %%
fips_codes.name.str.contains('Oglala').sum()
# Out:
# 0

# %%
fips_codes.name.str.contains('Kusilvak').sum()
# Out:
# 0

# %%
condition = spending[(spending['Count of Beneficiaries in County'] == 0) | (spending.County == 'Kusilvak') | (spending.County == 'Oglala Lakota')].index
spending.drop(condition, inplace=True)

# %%
condition = prevalence[(prevalence['Count of Beneficiaries in County'] == 0) | (prevalence.County == 'Kusilvak') | (prevalence.County == 'Oglala Lakota')].index
prevalence.drop(condition, inplace=True)

# %%
walkability = pd.merge(grouped, fips_codes,  how='left', left_on=['fips'], right_on = ['fips'])

# %%
spending_walkability = pd.merge(spending, walkability, how='left', left_on=['State', 'County'], right_on=['state', 'name'])

# %%
spending_walkability.isnull().sum()
# Out:
# State                               0
# County                              0
# Number of Chronic Conditions        0
# Count of Beneficiaries in County    0
# Prevalence (%)                      0
# Per Capita Medicare Spending ($)    0
# fips                                0
# NatWalkInd                          0
# TotPop                              0
# D1A                                 0
# D1B                                 0
# D1C                                 0
# R_PCTLOWWAGE                        0
# name                                0
# state                               0
# dtype: int64

# %%
sns.set_theme(style='darkgrid')
plt.rcParams['figure.dpi'] = 150

# %%
sns.boxplot(spending_walkability, y='Prevalence (%)', x='Number of Chronic Conditions', palette='pastel')
# Out:
# <Axes: xlabel='Number of Chronic Conditions', ylabel='Prevalence (%)'>

# %%
sns.set_palette('GnBu')
sns.histplot(spending_walkability, y='Per Capita Medicare Spending ($)', x='Number of Chronic Conditions', cbar=True)
# Out:
# <Axes: xlabel='Number of Chronic Conditions', ylabel='Per Capita Medicare Spending ($)'>

# %%
## perform One-Hot Encoding for Chronic Conditions
